# %%
# Layer Types
# 0 -> H -> High Index Layer Translational Matrix
# 1 -> L -> Low Index Layer Translational Matrix
# 2 -> M -> Medium Index Layer Translational Matrix
# 3 -> D -> Different Material 1 Layer Translational Matrix
# 4 -> T -> Different Material 2 Translational Matrix
# 5 -> V -> Different Material 2 Translational Matrix
# 6 -> A -> First Layer (Air) Inverse Dynamical Matrix
# 7 -> S -> Last Layer (Substrate) Dynamical Matrix

from multilayerAnalysis import MultilayerAnalysis
import numpy as np

## --------------------------------------------------------Inputs----------------------------------------------------
#designWaveLength = 1550.0
#thicknessDividerCoefficient = 4.0
#wavelengthRange = np.arange(1543, 1557, 0.01)
#refractiveIndexArr = np.array([1.8+0j, 1.5+0j, 1.45+0j, 3.073-3.383j, 3.073-3.383j, 3.073-3.383j, 1.000273+0j, 1.000273+0j], dtype=np.complex_)
#isThicknessAutoCalculatedArr = np.array([False, True, True, False, False, False, True, True], dtype=bool)
## If you want to select thickness automatically enter default value as 0.
#thicknessArr = np.array([2368.0555, 0, 0, 0, 0, 0, 0, 0])
## ------------------------------------------------------------------------------------------------------------------

# --------------------------------------------------------Inputs----------------------------------------------------
designWaveLength = 600.0
thicknessDividerCoefficient = 4.0
wavelengthRange = np.arange(400, 850, 0.1)
refractiveIndexArr = np.array([4.234+0j, 1.45+0j, 1.45+0j, 1.45+0j, 3.073-3.383j, 3.073-3.383j, 1.000273+0j, 1.52+0j], dtype=np.complex_)
isThicknessAutoCalculatedArr = np.array([True, True, True, False, False, False, True, True], dtype=bool)
# If you want to select thickness automatically enter default value as 0.
thicknessArr = np.array([0, 0, 0, 241.38, 5, 0, 0, 0])
# ------------------------------------------------------------------------------------------------------------------


# ----------------------You can write your own sequence here with using the letter table above.---------------------
multilayerSequenceThueWithMedium = "A[HLMLMHLMHHLMLMHHLMHLMLMH]^(1)S"
multilayerSequenceFibonacciWithMetalLayer = "AT[LHLHLLHL]^(2)D[LHLHLLHL]^(2)HS"
multilayerSequenceFibonacci = "A[LHLHLLHL]^(5)S"
multilayerSequenceTestThueFiboCombined = "A[HLLHLLHLHLLHL]^(2)[LHHLHLLHHLLHLHHL]^(1)A"
multilayerSequenceTestThueLuckyCombined = "AT[HLLHLHHLLHHLHLLH]^(2)HHLHHHHLHHLHHHLHLS"
multilayerSequenceTestFromLiterature = "A[[[H]^(18)L]^(19)H]^(19)[H]^(18)LS"
# -------------------------------------------------My Sequence Tests------------------------------------------------
# First Fibonacci mod8, then mod2 of Pisano Period. 1->H, 0->L and first two is switch to H to L.
multilayerSequenceTestPisano01 = "A(LLLHHLHHLHH)^(4)S"
# First Fibonacci mod7, then mod2 of Pisano Period. 1->H, 0->L.
multilayerSequenceTestPisano02 = "A(HHLHHHLLLLHLLLH)^(2)S"
# Pisano01 and Pisano02 series combined.
multilayerSequenceTestPisano03 = "A(LLLHHLHHLHH)^(2)(HHLHHHLLLLHLLLH)^(2)S"
# ------------------------------------------------------------------------------------------------------------------


MultilayerAnalysis(designWaveLength=designWaveLength,
                   thicknessDividerCoefficient=thicknessDividerCoefficient,
                   refractiveIndexArr=refractiveIndexArr,
                   isThicknessAutoCalculatedArr=isThicknessAutoCalculatedArr,
                   thicknessArr=thicknessArr,multilayerSequence=multilayerSequenceTestFromLiterature).PlotTheResults(wavelengthRange)
# Out:
# C:\Users\Bahadir\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Bahadir\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
